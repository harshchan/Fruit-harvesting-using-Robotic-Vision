# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path_bb = "/content/drive/My Drive/final_fruit_bb/Yolo/"
path="/content/drive/My Drive/final_fruit_dataset/"
sam="/content/drive/My Drive/sample_bb/images/"
sam_bb="/content/drive/My Drive/sample_bb/labels/"

# %%
import os
print(os.listdir(path))
for i,filename in enumerate(os.listdir(path)):
  print(path + filename)
  print(str(i))
  #print(os.path.isfile(path + filename))
  I = path + filename
  newI = path + str(i)+".jpg"
  #print(os.path.isfile(path + filename) == (path + str(i)+".jpg"))
  if (I == newI):
    print("Not renamed")
    continue
  else:
    os.rename(path + filename,path +"I_"+ str(i)+'.txt')
    print("Successfully renamed")
# Out:
# '\n\nimport os\nprint(os.listdir(path))\nfor i,filename in enumerate(os.listdir(path)):\n  print(path + filename)\n  print(str(i))\n  #print(os.path.isfile(path + filename))\n  I = path + filename\n  newI = path + str(i)+".jpg"\n  #print(os.path.isfile(path + filename) == (path + str(i)+".jpg"))\n  if (I == newI):\n    print("Not renamed")\n    continue\n  else:\n    os.rename(path + filename,path +"I_"+ str(i)+\'.txt\')\n    print("Successfully renamed")\n'

# %%
'''
import os

for i, filename in enumerate(os.listdir(sam)):
    os.rename(sam + filename, sam + 'AA_'+str(i) + ".jpg")

for i, filename in enumerate(os.listdir(sam_bb)):
    os.rename(sam_bb + filename, sam_bb + 'AA_'+str(i) + ".txt")
    '''
# Out:
# '\nimport os\n\nfor i, filename in enumerate(os.listdir(sam)):\n    os.rename(sam + filename, sam + \'AA_\'+str(i) + ".jpg")\n\nfor i, filename in enumerate(os.listdir(sam_bb)):\n    os.rename(sam_bb + filename, sam_bb + \'AA_\'+str(i) + ".txt")\n    '

# %%
'''
import os
for root, dirs, files in os.walk(sam_bb):
    for i,f in enumerate(files):
        absname = os.path.join(root, f)
        newname = os.path.join(root,'IMG_'+ str(i))
        os.rename(absname, newname)
for root, dirs, files in os.walk(sam):
    for i,f in enumerate(files):
        absname = os.path.join(root, f)
        newname = os.path.join(root,'IMG_'+ str(i))
        os.rename(absname, newname)

'''
# Out:
# "\nimport os\nfor root, dirs, files in os.walk(sam_bb):\n    for i,f in enumerate(files):\n        absname = os.path.join(root, f)\n        newname = os.path.join(root,'IMG_'+ str(i))\n        os.rename(absname, newname)\nfor root, dirs, files in os.walk(sam):\n    for i,f in enumerate(files):\n        absname = os.path.join(root, f)\n        newname = os.path.join(root,'IMG_'+ str(i))\n        os.rename(absname, newname)\n\n"

# %%
pathImages = "/content/drive/MyDrive/Dataset58_a/images/" # -----------------------------------Path of images-----------------------------------------------------------
pathTxt = "/content/drive/MyDrive/Dataset58_a/labels/" 

train_path_img=pathImages+'train/'
test_path_img=pathImages+'test/'
val_path_img=pathImages+'val/'

train_path_txt=pathTxt+'train/'
test_path_txt=pathTxt+'test/'
val_path_txt=pathTxt+'val/'

# -------------------------------------Path of txt files-------------------------------------------------------

import os


Img = []
txt = []

for i,filename in enumerate(os.listdir(pathImages)): # reading the imaged directory
  I = filename[:-4]
  Img.append(I)

for i,filename in enumerate(os.listdir(pathTxt)): # reading the txt directory
  t = filename[:-4]
  txt.append(t)


print(Img)
print(txt)
ImgTxt = []
for i in range(len(Img)): # converting to a single list with common image names and txt file names
  for j in range(len(txt)):
    if Img[i] == txt[j]:
      ImgTxt.append(Img[i])

print(ImgTxt)

#print(len(Img) == len(txt))
count = 1
for i in range(len(Img)):
  #print("Image : " + Img[i])
  #print("Txt : " + txt[j])
  print("count : " + str(count))
  print(pathImages + ImgTxt[i]+".jpg")
  print(pathImages + "I_" + str(count) + ".jpg")
  os.rename(pathImages + ImgTxt[i]+".jpg", pathImages + "I_" + str(count) + ".jpg") # renaming the image
  print("renamed Image")
  print(pathTxt + ImgTxt[i]+".txt")
  print(pathTxt + "I_" + str(count) + ".txt")
  os.rename(pathTxt + ImgTxt[i]+".txt", pathTxt + "I_" + str(count) + ".txt") # renaming the txt file
  print("renamed Txt")
  count += 1
# Out:
# ['IMG_896', 'IMG_897', 'IMG_898', 'IMG_899', 'IMG_900', 'IMG_902', 'IMG_903', 'IMG_904', 'IMG_907', 'IMG_908', 'IMG_909', 'IMG_910', 'IMG_911', 'IMG_912', 'IMG_913', 'IMG_914', 'IMG_921', 'IMG_920', 'IMG_915', 'IMG_918', 'IMG_919', 'IMG_916', 'IMG_917', 'IMG_42', 'IMG_45', 'IMG_56', 'IMG_53', 'IMG_48', 'IMG_64', 'IMG_63', 'IMG_55', 'IMG_46', 'IMG_50', 'IMG_66', 'IMG_62', 'IMG_49', 'IMG_67', 'IMG_59', 'IMG_52', 'IMG_47', 'IMG_51', 'IMG_60', 'IMG_57', 'IMG_61', 'IMG_68', 'IMG_43', 'IMG_54', 'IMG_58', 'IMG_65', 'IMG_44', 'IMG_300', 'IMG_286', 'IMG_302', 'IMG_296', 'IMG_293', 'IMG_291', 'IMG_295', 'IMG_304', 'IMG_283', 'IMG_299', 'IMG_294', 'IMG_290', 'IMG_307', 'IMG_289', 'IMG_285', 'IMG_297', 'IMG_292', 'IMG_306', 'IMG_298', 'IMG_310', 'IMG_288', 'IMG_282', 'IMG_301', 'IMG_303', 'IMG_309', 'IMG_305', 'IMG_284', 'IMG_287', 'IMG_308', 'IMG_281', 'IMG_311', 'IMG_624', 'IMG_620', 'IMG_622', 'IMG_623', 'IMG_626', 'IMG_616', 'IMG_625', 'IMG_610', 'IMG_621', 'IMG_612', 'IMG_611', 'IMG_627', '
# ...

# %%
# %cd /content/drive/My Drive/fina_fina
# Out:
# /content/drive/My Drive/fina_fina

# %%
pathImages="/content/drive/My_Drive/fin_fin/images/"
pathTxt="/content/drive/My_Drive/fin_fin/labels/"

# %%
qqq="/content/drive/My_Drive/new images"

# %%
pathImages="/content/drive/My Drive//images"
pathTxt="/content/drive/My Drive/dataset_correct/labels"
'''
# -------------------------------------Path of txt files-------------------------------------------------------
#print(train_path_img)
#print(test_path_img)
print(val_path_img)
print(train_path_txt)
print(test_path_txt)
print(val_path_txt)
#print(train_path_img)
'''

import os


Img = []
txt = []

for i,filename in enumerate(os.listdir(pathImages)): # reading the imaged directory
  I = filename[:-4]
  #print(I)
  Img.append(I)

for i,filename in enumerate(os.listdir(pathTxt)): # reading the txt directory
  t = filename[:-4]
  #print(t)
  txt.append(t)

# print(Img)
# print(txt)
# ImgTxt = []
# for i in range(len(Img)): # converting to a single list with common image names and txt file names
#   for j in range(len(txt)):
#     if Img[i] == txt[j]:
#       ImgTxt.append(Img[i])

# print(ImgTxt)


# for i in range(len(ImgTxt)):
#   if ImgTxt[i] == "t" :
#     print("t.jpg exists")

# #print(len(Img) == len(txt))


count = 1
xd='IMG_'
for h in txt:
  #print("Image : " + Img[i])
  #print("Txt : " + txt[j])
  #print(pathImages +xd+str(i)+".jpg")
  #print(pathTxt +xd+str(i)+".txt")


  
    
 
  if (os.path.exists(pathTxt +h+".txt")):
    os.rename(pathTxt +h+".txt", pathTxt + xd + str(count) + ".txt") # renaming the txt file
    os.rename(pathImages +h+".jpg", pathImages + xd+ str(count) + ".jpg") # renaming the txt file
    count += 1
    print("renamed both")
  else:
    print("skippped")
    continue
# Out:
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# skippped
# ...
