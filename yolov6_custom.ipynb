# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import sys
import torch
print(f"Python version: {sys.version}, {sys.version_info} ")
print(f"Pytorch version: {torch.__version__} ")
# Out:
# Python version: 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0], sys.version_info(major=3, minor=7, micro=13, releaselevel='final', serial=0)
# Pytorch version: 1.12.1+cu113

# %%
# %cd /content/drive/MyDrive/YOLOv6
# Out:
# /content/drive/MyDrive/YOLOv6

# %%
# REPLACE with your custom code snippet generated above to use your data

# !pip install "roboflow>=0.2.11"

from roboflow import Roboflow
rf = Roboflow(api_key="Av3Qxlu1BC3X3Ehw6jfQ")                       
project = rf.workspace("harshchan").project("yolov6trial")         
dataset = project.version(1).download("mt-yolov6")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 145 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 178 kB 41.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 64.9 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 138 kB 70.8 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.5 MB/s
# ...
#   Created wheel for roboflow: filename=roboflow-0.2.14-py3-none-any.whl size=24837 sha256=b2e9f83cf5b62650bd88a2435d44d660ca55a90517e532ab11d24be73d91242b
#   Stored in directory: /root/.cache/pip/wheels/c7/84/36/a6a32c749ead923690d15d20443fb53fa2fe10beaa408f371b
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=5884b60cf926c25254e894b965dc3271b21efcdbd29cac069157a9a4d63ab20e
# ...

# %%
! pip install addict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
  # run this cell to begin training
! python tools/train.py --batch 32 --conf configs/yolov6s.py --epochs 80 --img-size 416 --data {dataset.location}/data.yaml --device 0
# Out:
# Using 1 GPU for training...
# training args are: Namespace(batch_size=32, check_images=False, check_labels=False, conf_file='configs/yolov6s.py', data_path='/content/drive/.shortcut-targets-by-id/1A8LOnuM781Pv-6CEuxwrYoG7TZZGLCsa/YOLOv6/yolov6trial-1/data.yaml', device='0', dist_url='env://', epochs=80, eval_final_only=False, eval_interval=20, gpu_count=0, heavy_eval_range=50, img_size=416, local_rank=-1, name='exp', output_dir='./runs/train', rank=-1, resume=False, save_dir='runs/train/exp14', workers=8, world_size=1, write_trainbatch_tb=False)
#
# Train: Final numbers of valid images: 327/ labels: 327.
# 0.3s for dataset initialization.
# Convert to COCO format
# 100% 41/41 [00:00<00:00, 83559.99it/s]
# Convert to COCO format finished. Resutls saved in yolov6trial-1/annotations/instances_valid.json
# Val: Final numbers of valid images: 41/ labels: 41.
# 0.8s for dataset initialization.
# Model: Model(
#   (backbone): EfficientRep(
#     (stem): RepVGGBlock(
# ...

# %%
! pip install thop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Run evaluation
# !python tools/eval.py --data {dataset.location}/data.yaml --img-size 416 --weights runs/train/exp14/weights/best_ckpt.pt --device 0
# Out:
# Namespace(batch_size=32, conf_thres=0.001, data='/content/drive/.shortcut-targets-by-id/1A8LOnuM781Pv-6CEuxwrYoG7TZZGLCsa/YOLOv6/yolov6trial-1/data.yaml', device='0', half=False, img_size=416, iou_thres=0.65, name='exp', save_dir='runs/val/', task='val', weights='runs/train/exp14/weights/best_ckpt.pt')
# Loading checkpoint from runs/train/exp14/weights/best_ckpt.pt
#
# Fusing model...
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Switch model to deploy modality.
# Model Summary: Params: 17.19M, Gflops: 18.63
# Val: Checking formats of labels with 2 process(es):
# 41 label(s) found, 0 label(s) missing, 0 label(s) empty, 0 invalid label files: 100% 41/41 [00:00<00:00, 1168.01it/s]
# Convert to COCO format
# ...

# %%
# !python tools/infer.py --yaml {dataset.location}/data.yaml --img-size 416 --weights runs/train/exp14/weights/best_ckpt.pt --source {dataset.location}/images/test/ --device 0
# Out:
# Namespace(agnostic_nms=False, classes=None, conf_thres=0.25, device='0', half=False, hide_conf=False, hide_labels=False, img_size=416, iou_thres=0.45, max_det=1000, name='exp', project='runs/inference', save_img=True, save_txt=False, source='/content/drive/MyDrive/YOLOv6/yolov6trial-1/images/test/', view_img=False, weights='runs/train/exp14/weights/best_ckpt.pt', yaml='/content/drive/MyDrive/YOLOv6/yolov6trial-1/data.yaml')
# Save directory already existed
# Loading checkpoint from runs/train/exp14/weights/best_ckpt.pt
#
# Fusing model...
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Switch model to deploy modality.
# 100% 41/41 [00:14<00:00,  2.92it/s]
# Results saved to runs/inference/exp

# %%
# !python tools/eval.py --data {dataset.location}/data.yaml --img-size 416 --weights runs/train/exp9-86-epochs/weights/best_ckpt.pt --device 0
# Out:
# Namespace(batch_size=32, conf_thres=0.001, data='/content/drive/.shortcut-targets-by-id/1A8LOnuM781Pv-6CEuxwrYoG7TZZGLCsa/YOLOv6/yolov6trial-1/data.yaml', device='0', half=False, img_size=416, iou_thres=0.65, name='exp', save_dir='runs/val/', task='val', weights='runs/train/exp9-86-epochs/weights/best_ckpt.pt')
# Loading checkpoint from runs/train/exp9-86-epochs/weights/best_ckpt.pt
# Traceback (most recent call last):
#   File "tools/eval.py", line 93, in <module>
#     main(args)
#   File "tools/eval.py", line 88, in main
#     run(**vars(args))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "tools/eval.py", line 77, in run
#     model = val.init_model(model, weights, task)
#   File "/content/drive/.shortcut-targets-by-id/1A8LOnuM781Pv-6CEuxwrYoG7TZZGLCsa/YOLOv6/yolov6/core/evaler.py", line 46, in init_model
#     model = load_checkpoint(weights, map_location=self.device)
# ...

# %%
# infer on all images in our /test directory
# !python tools/infer.py --yaml {dataset.location}/data.yaml --img-size 416 --weights runs/train/exp14/weights/best_ckpt.pt --source /content/drive/MyDrive/strawberry_try2.mp4 --device 0
# Out:
# Namespace(agnostic_nms=False, classes=None, conf_thres=0.25, device='0', half=False, hide_conf=False, hide_labels=False, img_size=416, iou_thres=0.45, max_det=1000, name='exp', project='runs/inference', save_img=True, save_txt=False, source='/content/drive/MyDrive/strawberry_try2.mp4', view_img=False, weights='runs/train/exp14/weights/best_ckpt.pt', yaml='/content/drive/.shortcut-targets-by-id/1A8LOnuM781Pv-6CEuxwrYoG7TZZGLCsa/YOLOv6/yolov6trial-1/data.yaml')
# Loading checkpoint from runs/train/exp14/weights/best_ckpt.pt
#
# Fusing model...
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Switch model to deploy modality.
# 362it [00:12, 29.25it/s]
# Results saved to runs/inference/exp

# %%
# !python tools/infer.py --yaml {dataset.location}/data.yaml --img-size 416 --weights runs/train/exp14/weights/best_ckpt.pt --source /content/drive/MyDrive/strawberry_life.mp4 --device 0
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# sh: 0: getcwd() failed: No such file or directory
# Intel MKL FATAL ERROR: Cannot load /usr/local/lib/python3.7/dist-packages/torch/lib/libtorch_cpu.so.
